# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Apr 22 21:25:23 2020

@author: Rajalakshmi Selvaraj

Breast cancer develops from the breast tissue and shows different signs such as lumps, change in shape, changes in the texture of skin and pains in some cases. The detection of breast cancer happens through Mammography, ultrasound, analysing tissues, Biopsy and more methods. Each method has its unique way of identification and prone to manual mistakes. The usage of technology in classifying breast cancer improves diagnostic efficiency. The problem of classifying cancer can be done with the histopathology datasets, which is the accurate way of detecting it. 
Over 18 Lakh (Data source: Globocon 2018) breast cancer incidents are reported with a mortality rate of 25%. According to cancer research UK (Cancer Research UK, 2020), Over 50K cases are reported in the UK between 2015-2017, 11k deaths are reported in the same period due to breast cancer. There is a great need for classifying the cancer accurately to avoid more deaths.
In this proposal, the breast cancer classification of benign or malignant is carried out with the help of convolutional neural networks with simple SE-ResNet Model (Jiang Y, n.d.). The approach proposed in this work utilises CNN to extract features of histopathological images and classify the images into benign tumours and malignant tumours. 

Citiation
---------
[1] Jiang Y, Chen L, Zhang H, Xiao X (2019) Breast cancer histopathological image classification using convolutional neural networks with small SE-ResNet module. PLoS ONE 14(3): e0214587. https://doi.org/10.1371/journal.pone.0214587
[2] Mesut Toğaçar, Kutsal Baran Özkurt, Burhan Ergen, Zafer Cömert, BreastNet: A novel convolutional neural network model through histopathological images for the diagnosis of breast cancer, Physica A: Statistical Mechanics and its Applications, Volume
545,2020,123592,ISSN 0378-4371,https://doi.org/10.1016/j.physa.2019.123592.
[3] Deep Residual Learning, https://medium.com/@waya.ai/deep-residual-learning-9610bb62c355,

"""
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive 
from google.colab import auth 
from oauth2client.client import GoogleCredentials

from google.colab import drive
drive.mount('/content/gdrive')

from python_utils import *
import os
import warnings
warnings.filterwarnings('ignore')
import math
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import six
from PIL import Image
from albumentations import *

#Image Preprocessing
from skimage.transform import resize

#Plotting Metrics
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_fscore_support, accuracy_score, roc_auc_score, auc , roc_curve 

import logging
import datetime
import errno

#Keras Framework

from keras import models
from keras.models import Model,load_model
from keras import optimizers
from keras.optimizers import *
from keras.optimizers import Adagrad

from keras import layers
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import SeparableConv2D, Conv2D, MaxPooling2D, AveragePooling2D
from keras.layers import Input, Activation, Dense, Flatten, GlobalAveragePooling2D, Reshape, multiply
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation,Flatten,Dropout,Dense
from keras.layers.merge import add
from keras import backend as K
from keras.regularizers import l2
from keras.callbacks import EarlyStopping, LearningRateScheduler, TensorBoard, ModelCheckpoint, Callback

#Tensor Flow as Backend
import tensorflow as tf
from keras import backend as K

#Plotting Metrics
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
import pandas as pd

# Variables used in the code
SHAPE = (224, 224, 3)
BATCH_SIZE = 32
EPOCHS = 50
N_SPLITS = 5
SEED = 1881
TRAIN_TEST_RATIO = 0.2
num_classes = 2
BASE_DIR     = "/content/gdrive/My Drive/BreastCancer/breast/"
DATASET_MODE = ["40X", "100X", "200X", "400X"]
base_path = "/content/gdrive/My Drive/"
img_height = 224
img_width = 224
img_channels = 3
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# Using TensorFlow backend.

# %% [markdown]
# KERAS

# %% [markdown]
# Neural Networks with Keras Keras is a high-level Deep Learning API that allows you to easily build, train and execute of neural networks. Its documentation is available at https://keras.io/. Keras is quite popular because of its ease of use and flexibility. To perform the heavy computations required by neural networks, Keras relies on a computation backend. We will be using Tensorflow as such backend, and for that reason we will be importing keras as follows:

# %% [markdown]
# Dataset Pre-Processing

# %% [markdown]
# BreakHis dataset comprises of 7909 breast cancer images under two main categories: benign or malignant. 2440 images are available in the Benign class and the malignant class contains 5429 images. Each class has four sub-categories. The sub-categories of benign cancer are listed as Adenosis (A), Fibroadenoma (F), Tubular Adenoma (TA), and Phyllodes Tumor (PT). The four sub-categories of malignant cancer are Ductal Carcinoma (DC), Lobular Carcinoma (LC), Mucinous Carcinoma (MC), and Papillary Carcinoma (PC).

# %% [markdown]
# Image Pre-Processing and Augmentation
#
# The RGB images are converted into Arrays. The shape of the array corresponds to the shape of the image. For better attributes extraction, data augmentation is used for the samples. Adding Augmentation parameters such as flip, shift, brightness, rotation and change yield better results.The processed data is split in to train and test data with the split ratio.

# %%
class BreastDataset:
    
    """
    input_shape           --> TUPLE.image size
    batch_size            --> INT.data size for every iteration
    orders                --> LIST.images used for cross validation
    base_dir              --> STR.the directory which contains images of Benign and Malignant under directories.
    dataset_mode          --> STR. type of magnification (eg: 4OX, 100X etc)
    seed                  --> INT. This allow to dataset generator to more reproduciable and it ensures that x and y are shuffled with compatible.
    augment               --> BOOL. Augment data or not.
    train_test_ratio      --> Percentage of test data.
    ---------
    GENERAL_CLASSES       --> LIST.["benign", "malignant"]
    BENIGN_SUB_CLASSES    --> LIST.["adenosis", "fibroadenoma", "phyllodes_tumor", "tubular_adenoma"]
    MALIGNANT_SUB_CLASSES --> LIST.["ductal_carcinoma", "lobular_carcinoma", "mucinous_carcinoma", "papillary_carcinoma"]
    """
    
    def __init__(self, input_shape, batch_size, orders, base_dir, dataset_mode, seed, train_test_ratio, augment=True):
        self.SHAPE                 = input_shape
        self.BATCH_SIZE            = batch_size
        self.arr                   = orders
        self.DATASET_MODE          = dataset_mode
        self.SEED                  = seed
        self.TT_RATIO              = train_test_ratio
        self.AUG                   = augment
        
        self.BASE_DIR              = base_dir
        self.GENERAL_CLASSES       = ["benign", "malignant"]
        self.BENIGN_SUB_CLASSES    = ["adenosis", "fibroadenoma", "phyllodes_tumor", "tubular_adenoma"]
        self.MALIGNANT_SUB_CLASSES = ["ductal_carcinoma", "lobular_carcinoma", "mucinous_carcinoma", "papillary_carcinoma"]
        
        
    def get_paths_n_labels(self):

        x      = []
        label = []
        
        for data_mode in self.DATASET_MODE:
            for ix1, a in enumerate(self.GENERAL_CLASSES):
                if ix1 == 0:
                    for ix2, b in enumerate(self.BENIGN_SUB_CLASSES):
                        path1 = self.BASE_DIR+a+"/SOB/"+b
                        for c in os.listdir(path1):
                            path2 = path1+"/"+c+"/"+data_mode
                            for img_name in os.listdir(path2):
                                path3 = path2+"/"+img_name

                                # x
                                img_path = path3 

                                # y - BENIGN OR MALIGNANT
                                main_targets = np.zeros((2), dtype=np.float32) 
                                main_targets[ix1] = 1.

                                # Store the values
                                x.append(img_path)
                                label.append(main_targets)


                if ix1 == 1:
                    for ix2, b in enumerate(self.MALIGNANT_SUB_CLASSES):
                        path1 = self.BASE_DIR+a+"/SOB/"+b
                        for c in os.listdir(path1):
                            path2 = path1+"/"+c+"/"+data_mode
                            for img_name in os.listdir(path2):
                                path3 = path2+"/"+img_name

                                # x
                                img_path = path3 

                                # y - BENIGN OR MALIGNANT
                                main_targets = np.zeros((2), dtype=np.float32) 
                                main_targets[ix1] = 1.

                                # Store the values
                                x.append(img_path)
                                label.append(main_targets)
                                #print("Log1:", x,label)                           
        return x, label
    
    def __len__(self):
        return len(self.get_paths_n_labels()[0])
    
    def get_img(self, img_path):
        img = Image.open(img_path)
        return np.array(img)
    
    # initialize the training data augmentation object
    def augmenting(self, img):
        if self.AUG:
            augment = Compose([VerticalFlip(p=0.5),
                               HorizontalFlip(p=0.5),
                               RandomBrightnessContrast(p=0.3),
                               ShiftScaleRotate(p=0.5, shift_limit=0.2, scale_limit=0.2, rotate_limit=20)])  
        else:
            augment = Compose([])  

        img = augment(image=img)['image']
        return img
    
    #Resize of the image
    def resize_and_normalize(self, img):
        img = resize(img, self.SHAPE)
        return img
    
    #Shuffling of the data randomly using the SEED parameter
    def get_shuffled_data(self):
        img_paths, labels = self.get_paths_n_labels()

        np.random.seed(self.SEED) 
        np.random.shuffle(img_paths)
        
        np.random.seed(self.SEED) 
        np.random.shuffle(labels)
        
        return img_paths, labels
        
    def split_train_test(self, get):  # get=={"train","test"}
        img_paths, labels = self.get_shuffled_data()
        x_train, x_test, y_train, y_test = train_test_split(img_paths, labels, test_size=self.TT_RATIO, random_state=self.SEED)
        
        if get=='train':
            
            return x_train, y_train
        
        elif get=='test':
           
            return x_test, y_test
    
    def data_generator(self):
        img_paths, labels = self.split_train_test(get="train")
        
        while True:
            x = np.empty((self.BATCH_SIZE,)+self.SHAPE, dtype=np.float32)
            y = np.empty((self.BATCH_SIZE, 2), dtype=np.float32)

            batch = np.random.choice(self.arr, self.BATCH_SIZE)

            for ix, id_ in enumerate(batch):
                # x
                img_path = img_paths[id_]
                img = self.get_img(img_path)
                img = self.augmenting(img)
                img = self.resize_and_normalize(img)
                  
                # y 
                label = labels[id_]
             
                # Store the values    
                x[ix] = img
                y[ix] = label

            yield x, y
            
            
dataset = BreastDataset(SHAPE, 1, range(4), BASE_DIR, DATASET_MODE, SEED, TRAIN_TEST_RATIO, augment=True)


ROW_AXIS = 1
COL_AXIS = 2
CHANNEL_AXIS = 3

# %% [markdown]
# Simple SE ResNet

# %% [markdown]
# SE-ResNet is built upon the convolution operation, which extracts informative features by fusing spatial and channel-wise information within local receptive fields.
# SE proposed a weighted representation on a layer rather an equal representation. By learning the corresponding weights of each channel in the SE-block, it introduces an addition hyperparameter, r (ratio) to be used. For c number of channels, it attempts to learn a (sigmoidal) vector of size c (a tensor of 1x1xc to be exact) and multiplies it with the current tensor in the given layer.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def squeeze_excite_block(input, ratio = 16):
    init = input
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1  # compute channel axis
    filters = init._keras_shape[channel_axis]  # infer input number of filters
    shape = (1, 1, filters) if K.image_data_format() == 'channels_last' else (filters, 1, 1)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(shape)(se)
    se = Dense(filters // ratio, activation = "relu", kernel_initializer = "he_normal", use_bias = False)(se)
    se = Dense(filters, activation = "sigmoid", kernel_initializer = "he_normal", use_bias = False)(se)

    output = multiply([init, se])
    
    return output



ConvFlag = 1
dropRate = 0.3

def residual_network(x):
  
    def add_common_layers(y):
        y = layers.BatchNormalization()(y)
        y = layers.LeakyReLU()(y)

        return y

    def grouped_convolution(y, nb_channels, _strides):
        # when `ConvFlag` == 1 this is just a standard convolution
        if ConvFlag == 1:
            return layers.Conv2D(nb_channels, kernel_size=(3, 3), strides=_strides, padding='same')(y)
  

    def residual_block(y, nb_channels_in, nb_channels_out, _strides=(1, 1), _Flag=False):
        """
        The Network consists of a stack of residual blocks. 
        - If producing spatial maps of the same size, the blocks share the same hyper-parameters (width and filter sizes).
        - Each time the spatial map is down-sampled by a factor of 2, the width of the blocks is multiplied by a factor of 2.
        """
        shortcut = y

        # The residual building block as a bottleneck design to make the network more economical
        y = layers.Conv2D(nb_channels_in, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
        y = add_common_layers(y)

        
        y = grouped_convolution(y, nb_channels_in, _strides=_strides)
        y = add_common_layers(y)

        y = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
        # batch normalization is employed after aggregating the transformations and before adding to the shortcut
        y = layers.BatchNormalization()(y)

        # identity block used directly when the input and output are of the same dimensions
        if _Flag or _strides != (1, 1):
            # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions)
            # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
            shortcut = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)

        y = squeeze_excite_block(y)
        y = layers.add([shortcut, y])

        # relu is performed right after each batch normalization,
        # expect for the output of the block where relu is performed after the adding to the shortcut
        y = layers.LeakyReLU()(y)

        return y

    # conv1
    x = layers.Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same')(x)
    x = add_common_layers(x)

    # conv2
    x = layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    for i in range(3):
        project_shortcut = True if i == 0 else False
        x = residual_block(x, 128, 256, _Flag=project_shortcut)

    # conv3
    for i in range(4):
        # down-sampling is performed by conv3_1, conv4_1, and conv5_1 with a stride of 2
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 256, 512, _strides=strides)


    # conv4
    for i in range(6):
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 512, 1024, _strides=strides)

    # conv5
    for i in range(3):
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 1024, 2048, _strides=strides)
    

   
    x = layers.AveragePooling2D((7,7), name="avg_pool")(x)
    x = Flatten()(x)
    # softmax classifier
    x = layers.Dense(2,activation='softmax')(x)

    # return the constructed network architecture
    return x


image_tensor = layers.Input(shape=(img_height, img_width, img_channels))
network_output = residual_network(image_tensor)
  
model = models.Model(inputs=[image_tensor], outputs=[network_output])
print(model.summary())


INIT_LR = 1e-3

kf = KFold(n_splits=N_SPLITS, random_state=SEED, shuffle=True)

for ix, (train_index, test_index) in enumerate(kf.split(range(len(dataset.split_train_test("train")[0])))):
    # initialize the training data                                           
    tg = BreastDataset(SHAPE, BATCH_SIZE, train_index, BASE_DIR, DATASET_MODE, SEED, TRAIN_TEST_RATIO, augment=True)

    # initialize the validation data
    vg = BreastDataset(SHAPE, BATCH_SIZE, test_index , BASE_DIR, DATASET_MODE, SEED, TRAIN_TEST_RATIO, augment=False)
           
    #initialize our Model and Compile with Adaptive Gradient Algorithm as Optimization method
    opt = Adagrad(lr=INIT_LR, decay=INIT_LR / EPOCHS)
    model.compile(loss="binary_crossentropy", optimizer=opt,metrics=["accuracy"])
   
#Early stopping to avoid the overfitting
class EarlyStoppingByLossVal(Callback):
    def __init__(self, monitor='val_loss', value=0.00001, verbose=0):
        super(Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if current is None:
            warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)

        if current < self.value:
            if self.verbose > 0:
                print("Epoch %05d: early stopping THR" % epoch)
            self.model.stop_training = True


filepath = '/content/gdrive/My Drive/seweights_0306.hdf5'

#Callback with Earlystopping and Model Checkpoint
cbks = [
    EarlyStoppingByLossVal(monitor='val_loss', value=0.00001, verbose=1),
    ModelCheckpoint(filepath,monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
]

#Training of the Model
hist = model.fit_generator(tg.data_generator(),
                           steps_per_epoch=len(train_index)//BATCH_SIZE,
                        epochs=EPOCHS,
                        verbose=2,
                        callbacks=cbks,
                        validation_data=vg.data_generator(),
                        validation_steps=len(test_index)//BATCH_SIZE)

#Saving the model
model.save('/content/gdrive/My Drive/seResnetcode_0206.h5')
print("Saved model to disk")

#Plotting of Accuracy and Loss graphs

# summarize history for Accuracy
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for 

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 112, 112, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 112, 112, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)   0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 128)  8320        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 56, 56, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 128)  147584      leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 56, 56, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 256)  33024       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 256)          0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 1, 16)     4096        reshape_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 1, 256)    4096        dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 56, 56, 256)  0           batch_normalization_4[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 256)  0           batch_normalization_5[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 56, 56, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 128)  32896       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 128)  147584      leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 56, 56, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 256)  33024       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 256)          0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 1, 16)     4096        reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1, 1, 256)    4096        dense_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 56, 56, 256)  0           batch_normalization_8[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 56, 56, 256)  0           leaky_re_lu_4[0][0]
#                                                                  multiply_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 56, 56, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 128)  32896       leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 56, 56, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 128)  147584      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 56, 56, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 56, 56, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 256)  33024       leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 256)          0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1, 1, 256)    0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1, 1, 16)     4096        reshape_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1, 1, 256)    4096        dense_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 56, 56, 256)  0           batch_normalization_11[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 256)  0           leaky_re_lu_7[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 56, 56, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 256)  65792       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 56, 56, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 256)  590080      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 28, 28, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 28, 28, 256)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 512)  131584      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 28, 28, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 512)          0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 32)     16384       reshape_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 512)  131584      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 512)    16384       dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 512)  2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 28, 28, 512)  0           batch_normalization_14[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           batch_normalization_15[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 256)  131328      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 28, 28, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 28, 28, 256)  590080      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 28, 28, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 28, 28, 512)  131584      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 512)  2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 512)          0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 32)     16384       reshape_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 512)    16384       dense_9[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 28, 28, 512)  0           batch_normalization_18[0][0]
#                                                                  dense_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           leaky_re_lu_13[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 28, 28, 256)  131328      leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 256)  1024        conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 28, 28, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 28, 28, 256)  590080      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 28, 28, 256)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 512)  131584      leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 512)  2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_6 (Glo (None, 512)          0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 32)     16384       reshape_6[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 512)    16384       dense_11[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 28, 28, 512)  0           batch_normalization_21[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           leaky_re_lu_16[0][0]
#                                                                  multiply_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 256)  131328      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 256)  1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 28, 28, 256)  0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 256)  590080      leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 28, 28, 256)  1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 28, 28, 256)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 512)  131584      leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 28, 28, 512)  2048        conv2d_24[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_7 (Glo (None, 512)          0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 512)    0           global_average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1, 1, 32)     16384       reshape_7[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1, 1, 512)    16384       dense_13[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 28, 28, 512)  0           batch_normalization_24[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 28, 28, 512)  0           leaky_re_lu_19[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 28, 28, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 512)  262656      leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 28, 28, 512)  2048        conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 28, 28, 512)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 512)  2359808     leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 512)  2048        conv2d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 1024) 525312      leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 1024) 4096        conv2d_27[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 1024)         0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 1024)   0           global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 1, 1, 64)     65536       reshape_8[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 1024) 525312      leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 1, 1, 1024)   65536       dense_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 14, 14, 1024) 4096        conv2d_28[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 14, 14, 1024) 0           batch_normalization_27[0][0]
#                                                                  dense_16[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           batch_normalization_28[0][0]
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 512)  524800      leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 14, 14, 512)  2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 512)  2359808     leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 14, 14, 512)  2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 1024) 525312      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 14, 14, 1024) 4096        conv2d_31[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 1024)         0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 1024)   0           global_average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 1, 1, 64)     65536       reshape_9[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 1, 1, 1024)   65536       dense_17[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 14, 14, 1024) 0           batch_normalization_31[0][0]
#                                                                  dense_18[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           leaky_re_lu_25[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 512)  524800      leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 14, 14, 512)  2048        conv2d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 512)  2359808     leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 14, 14, 512)  2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 1024) 525312      leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 14, 14, 1024) 4096        conv2d_34[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_10 (Gl (None, 1024)         0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 1024)   0           global_average_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1, 1, 64)     65536       reshape_10[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1, 1, 1024)   65536       dense_19[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 14, 14, 1024) 0           batch_normalization_34[0][0]
#                                                                  dense_20[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           leaky_re_lu_28[0][0]
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 512)  524800      leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 14, 14, 512)  2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 512)  2359808     leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 14, 14, 512)  2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 1024) 525312      leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 14, 14, 1024) 4096        conv2d_37[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_11 (Gl (None, 1024)         0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 1024)   0           global_average_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 1, 1, 64)     65536       reshape_11[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 1, 1, 1024)   65536       dense_21[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 14, 14, 1024) 0           batch_normalization_37[0][0]
#                                                                  dense_22[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           leaky_re_lu_31[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 512)  524800      leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 14, 14, 512)  2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 512)  2359808     leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 14, 14, 512)  2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 1024) 525312      leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 14, 14, 1024) 4096        conv2d_40[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 1024)         0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 1, 1, 1024)   0           global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1, 1, 64)     65536       reshape_12[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1, 1, 1024)   65536       dense_23[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 14, 14, 1024) 0           batch_normalization_40[0][0]
#                                                                  dense_24[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           leaky_re_lu_34[0][0]
#                                                                  multiply_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 512)  524800      leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 14, 14, 512)  2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 512)  2359808     leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 14, 14, 512)  2048        conv2d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 14, 14, 512)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 1024) 525312      leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 14, 14, 1024) 4096        conv2d_43[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 1024)         0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 1, 1, 1024)   0           global_average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 1, 1, 64)     65536       reshape_13[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1, 1, 1024)   65536       dense_25[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 14, 14, 1024) 0           batch_normalization_43[0][0]
#                                                                  dense_26[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           leaky_re_lu_37[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 1024) 1049600     leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 14, 14, 1024) 4096        conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 14, 14, 1024) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 1024)   9438208     leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 7, 7, 1024)   4096        conv2d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 7, 7, 1024)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 2048)   2099200     leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 7, 7, 2048)   8192        conv2d_46[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_14 (Gl (None, 2048)         0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# reshape_14 (Reshape)            (None, 1, 1, 2048)   0           global_average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1, 1, 128)    262144      reshape_14[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 2048)   2099200     leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 1, 1, 2048)   262144      dense_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 7, 7, 2048)   8192        conv2d_47[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 7, 7, 2048)   0           batch_normalization_46[0][0]
#                                                                  dense_28[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           batch_normalization_47[0][0]
#                                                                  multiply_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 1024)   2098176     leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 7, 7, 1024)   4096        conv2d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 7, 7, 1024)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 1024)   9438208     leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 7, 7, 1024)   4096        conv2d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 7, 7, 1024)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 2048)   2099200     leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 7, 7, 2048)   8192        conv2d_50[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_15 (Gl (None, 2048)         0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# reshape_15 (Reshape)            (None, 1, 1, 2048)   0           global_average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 1, 1, 128)    262144      reshape_15[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 1, 1, 2048)   262144      dense_29[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 7, 7, 2048)   0           batch_normalization_50[0][0]
#                                                                  dense_30[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           leaky_re_lu_43[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 1024)   2098176     leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 7, 7, 1024)   4096        conv2d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 7, 7, 1024)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 1024)   9438208     leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 7, 7, 1024)   4096        conv2d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 7, 7, 1024)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 2048)   2099200     leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 7, 7, 2048)   8192        conv2d_53[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_16 (Gl (None, 2048)         0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# reshape_16 (Reshape)            (None, 1, 1, 2048)   0           global_average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 1, 1, 128)    262144      reshape_16[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1, 1, 2048)   262144      dense_31[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 7, 7, 2048)   0           batch_normalization_53[0][0]
#                                                                  dense_32[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 2048)   0           leaky_re_lu_46[0][0]
#                                                                  multiply_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 7, 7, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 2)            4098        flatten_1[0][0]
# ==================================================================================================
# Total params: 69,455,618
# Trainable params: 69,387,394
# Non-trainable params: 68,224
# __________________________________________________________________________________________________
# None
# Epoch 1/50
#  - 1542s - loss: 0.7265 - accuracy: 0.7912 - val_loss: 1.6312 - val_accuracy: 0.6977
#
# Epoch 00001: val_accuracy improved from -inf to 0.69766, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 2/50
#  - 695s - loss: 0.4888 - accuracy: 0.8152 - val_loss: 0.6110 - val_accuracy: 0.7023
#
# Epoch 00002: val_accuracy improved from 0.69766 to 0.70234, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 3/50
#  - 443s - loss: 0.4095 - accuracy: 0.8326 - val_loss: 0.6842 - val_accuracy: 0.7102
#
# Epoch 00003: val_accuracy improved from 0.70234 to 0.71016, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 4/50
#  - 354s - loss: 0.3974 - accuracy: 0.8480 - val_loss: 0.3351 - val_accuracy: 0.8078
#
# Epoch 00004: val_accuracy improved from 0.71016 to 0.80781, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 5/50
#  - 315s - loss: 0.3762 - accuracy: 0.8543 - val_loss: 0.1799 - val_accuracy: 0.8680
#
# Epoch 00005: val_accuracy improved from 0.80781 to 0.86797, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 6/50
#  - 306s - loss: 0.3902 - accuracy: 0.8547 - val_loss: 0.5615 - val_accuracy: 0.8344
#
# Epoch 00006: val_accuracy did not improve from 0.86797
# Epoch 7/50
#  - 303s - loss: 0.3233 - accuracy: 0.8697 - val_loss: 0.1642 - val_accuracy: 0.8945
#
# Epoch 00007: val_accuracy improved from 0.86797 to 0.89453, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 8/50
#  - 293s - loss: 0.3187 - accuracy: 0.8686 - val_loss: 0.2173 - val_accuracy: 0.8516
#
# Epoch 00008: val_accuracy did not improve from 0.89453
# Epoch 9/50
#  - 297s - loss: 0.3096 - accuracy: 0.8736 - val_loss: 0.4785 - val_accuracy: 0.8758
#
# Epoch 00009: val_accuracy did not improve from 0.89453
# Epoch 10/50
#  - 296s - loss: 0.2926 - accuracy: 0.8834 - val_loss: 0.1391 - val_accuracy: 0.8875
#
# Epoch 00010: val_accuracy did not improve from 0.89453
# Epoch 11/50
#  - 289s - loss: 0.3059 - accuracy: 0.8809 - val_loss: 0.2786 - val_accuracy: 0.8672
#
# Epoch 00011: val_accuracy did not improve from 0.89453
# Epoch 12/50
#  - 296s - loss: 0.3015 - accuracy: 0.8715 - val_loss: 0.1343 - val_accuracy: 0.8930
#
# Epoch 00012: val_accuracy did not improve from 0.89453
# Epoch 13/50
#  - 293s - loss: 0.2638 - accuracy: 0.8869 - val_loss: 0.5515 - val_accuracy: 0.8414
#
# Epoch 00013: val_accuracy did not improve from 0.89453
# Epoch 14/50
#  - 291s - loss: 0.2540 - accuracy: 0.8891 - val_loss: 0.1952 - val_accuracy: 0.9211
#
# Epoch 00014: val_accuracy improved from 0.89453 to 0.92109, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 15/50
#  - 292s - loss: 0.2506 - accuracy: 0.8934 - val_loss: 0.3018 - val_accuracy: 0.8109
#
# Epoch 00015: val_accuracy did not improve from 0.92109
# Epoch 16/50
#  - 297s - loss: 0.2310 - accuracy: 0.8994 - val_loss: 0.3545 - val_accuracy: 0.8703
#
# Epoch 00016: val_accuracy did not improve from 0.92109
# Epoch 17/50
#  - 291s - loss: 0.2243 - accuracy: 0.9047 - val_loss: 0.1925 - val_accuracy: 0.9156
#
# Epoch 00017: val_accuracy did not improve from 0.92109
# Epoch 18/50
#  - 288s - loss: 0.2356 - accuracy: 0.8998 - val_loss: 0.1852 - val_accuracy: 0.9148
#
# Epoch 00018: val_accuracy did not improve from 0.92109
# Epoch 19/50
#  - 280s - loss: 0.2306 - accuracy: 0.9029 - val_loss: 0.6789 - val_accuracy: 0.8641
#
# Epoch 00019: val_accuracy did not improve from 0.92109
# Epoch 20/50
#  - 282s - loss: 0.2218 - accuracy: 0.9037 - val_loss: 0.2062 - val_accuracy: 0.8992
#
# Epoch 00020: val_accuracy did not improve from 0.92109
# Epoch 21/50
#  - 278s - loss: 0.2092 - accuracy: 0.9156 - val_loss: 0.3427 - val_accuracy: 0.8539
#
# Epoch 00021: val_accuracy did not improve from 0.92109
# Epoch 22/50
#  - 276s - loss: 0.2205 - accuracy: 0.9094 - val_loss: 0.1404 - val_accuracy: 0.9281
#
# Epoch 00022: val_accuracy improved from 0.92109 to 0.92813, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 23/50
#  - 275s - loss: 0.1968 - accuracy: 0.9170 - val_loss: 0.2030 - val_accuracy: 0.8188
#
# Epoch 00023: val_accuracy did not improve from 0.92813
# Epoch 24/50
#  - 273s - loss: 0.1985 - accuracy: 0.9156 - val_loss: 0.1782 - val_accuracy: 0.8867
#
# Epoch 00024: val_accuracy did not improve from 0.92813
# Epoch 25/50
#  - 277s - loss: 0.2048 - accuracy: 0.9109 - val_loss: 0.1673 - val_accuracy: 0.9273
#
# Epoch 00025: val_accuracy did not improve from 0.92813
# Epoch 26/50
#  - 276s - loss: 0.1869 - accuracy: 0.9215 - val_loss: 0.3634 - val_accuracy: 0.8734
#
# Epoch 00026: val_accuracy did not improve from 0.92813
# Epoch 27/50
#  - 274s - loss: 0.1993 - accuracy: 0.9146 - val_loss: 0.7420 - val_accuracy: 0.8234
#
# Epoch 00027: val_accuracy did not improve from 0.92813
# Epoch 28/50
#  - 271s - loss: 0.1924 - accuracy: 0.9217 - val_loss: 0.2944 - val_accuracy: 0.8883
#
# Epoch 00028: val_accuracy did not improve from 0.92813
# Epoch 29/50
#  - 273s - loss: 0.1808 - accuracy: 0.9227 - val_loss: 0.4128 - val_accuracy: 0.8695
#
# Epoch 00029: val_accuracy did not improve from 0.92813
# Epoch 30/50
#  - 281s - loss: 0.1730 - accuracy: 0.9234 - val_loss: 0.1259 - val_accuracy: 0.9172
#
# Epoch 00030: val_accuracy did not improve from 0.92813
# Epoch 31/50
#  - 283s - loss: 0.1812 - accuracy: 0.9203 - val_loss: 0.4199 - val_accuracy: 0.8883
#
# Epoch 00031: val_accuracy did not improve from 0.92813
# Epoch 32/50
#  - 281s - loss: 0.1830 - accuracy: 0.9217 - val_loss: 0.3584 - val_accuracy: 0.8414
#
# Epoch 00032: val_accuracy did not improve from 0.92813
# Epoch 33/50
#  - 277s - loss: 0.1597 - accuracy: 0.9330 - val_loss: 0.1674 - val_accuracy: 0.9328
#
# Epoch 00033: val_accuracy improved from 0.92813 to 0.93281, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 34/50
#  - 275s - loss: 0.1753 - accuracy: 0.9293 - val_loss: 0.0941 - val_accuracy: 0.8687
#
# Epoch 00034: val_accuracy did not improve from 0.93281
# Epoch 35/50
#  - 275s - loss: 0.1614 - accuracy: 0.9307 - val_loss: 0.4220 - val_accuracy: 0.8367
#
# Epoch 00035: val_accuracy did not improve from 0.93281
# Epoch 36/50
#  - 276s - loss: 0.1600 - accuracy: 0.9369 - val_loss: 0.1397 - val_accuracy: 0.9414
#
# Epoch 00036: val_accuracy improved from 0.93281 to 0.94141, saving model to /content/gdrive/My Drive/seweights_0306.hdf5
# Epoch 37/50
#  - 279s - loss: 0.1660 - accuracy: 0.9281 - val_loss: 0.5287 - val_accuracy: 0.8516
#
# Epoch 00037: val_accuracy did not improve from 0.94141
# Epoch 38/50
#  - 277s - loss: 0.1570 - accuracy: 0.9365 - val_loss: 1.3767 - val_accuracy: 0.7633
#
# Epoch 00038: val_accuracy did not improve from 0.94141
# Epoch 39/50
#  - 276s - loss: 0.1675 - accuracy: 0.9279 - val_loss: 0.1628 - val_accuracy: 0.9312
#
# Epoch 00039: val_accuracy did not improve from 0.94141
# Epoch 40/50
#  - 281s - loss: 0.1418 - accuracy: 0.9396 - val_loss: 0.1486 - val_accuracy: 0.9398
#
# Epoch 00040: val_accuracy did not improve from 0.94141
# Epoch 41/50
#  - 275s - loss: 0.1562 - accuracy: 0.9363 - val_loss: 0.2157 - val_accuracy: 0.9367
#
# Epoch 00041: val_accuracy did not improve from 0.94141
# Epoch 42/50
#  - 276s - loss: 0.1484 - accuracy: 0.9359 - val_loss: 0.3696 - val_accuracy: 0.8617
#
# Epoch 00042: val_accuracy did not improve from 0.94141
# Epoch 43/50
#  - 273s - loss: 0.1547 - accuracy: 0.9361 - val_loss: 0.2952 - val_accuracy: 0.8758
#
# Epoch 00043: val_accuracy did not improve from 0.94141
# Epoch 44/50
#  - 272s - loss: 0.1469 - accuracy: 0.9400 - val_loss: 0.1807 - val_accuracy: 0.9133
#
# Epoch 00044: val_accuracy did not improve from 0.94141
# Epoch 45/50
#  - 278s - loss: 0.1520 - accuracy: 0.9381 - val_loss: 0.1650 - val_accuracy: 0.9383
#
# Epoch 00045: val_accuracy did not improve from 0.94141
# Epoch 46/50
#  - 274s - loss: 0.1483 - accuracy: 0.9381 - val_loss: 0.2593 - val_accuracy: 0.8086
#
# Epoch 00046: val_accuracy did not improve from 0.94141
# Epoch 47/50
#  - 276s - loss: 0.1347 - accuracy: 0.9463 - val_loss: 0.7786 - val_accuracy: 0.8148
#
# Epoch 00047: val_accuracy did not improve from 0.94141
# Epoch 48/50
#  - 277s - loss: 0.1430 - accuracy: 0.9408 - val_loss: 0.1598 - val_accuracy: 0.8992
#
# Epoch 00048: val_accuracy did not improve from 0.94141
# Epoch 49/50
#  - 275s - loss: 0.1354 - accuracy: 0.9438 - val_loss: 0.0153 - val_accuracy: 0.9172
#
# Epoch 00049: val_accuracy did not improve from 0.94141
# Epoch 50/50
#  - 278s - loss: 0.1366 - accuracy: 0.9465 - val_loss: 0.2294 - val_accuracy: 0.8797
#
# Epoch 00050: val_accuracy did not improve from 0.94141
# Saved model to disk

# %% [markdown]
# Evaluation of the Model
#
# Once the trained model is available, it is evaluated by the testing data, and once it is completed, the trained model is used for prediction of results. In our case, feeding of any image yields classification results as benign or malignant.

# %%
# initialize and get the testing data
def get_test_data():
    gen = BreastDataset(SHAPE, BATCH_SIZE, range(1), BASE_DIR, DATASET_MODE, SEED, TRAIN_TEST_RATIO, augment=False).split_train_test("test")
                       
    x = np.empty((len(gen[0]),)+SHAPE, dtype=np.float32)
    y = np.empty((len(gen[1]), 2), dtype=np.float32)
    
    for ix, path in tqdm(enumerate(gen[0])):
        img = np.array(Image.open(gen[0][ix]))
        img = resize(img, SHAPE)

        label = gen[1][ix]

        x[ix] = img
        y[ix] = label
        
    return x, y

# %%
#Evaluation of the Model
print("[INFO] evaluating network...")
x, y = get_test_data()
models = []
for i in range(5):
    
    model = load_model("/content/gdrive/My Drive/Resnetcode_2705.h5")
    print(model.evaluate(x, y, verbose=0))
    models.append(model)
# Out:
# [INFO] evaluating network...
# 1604it [08:08,  3.28it/s]
# [0.1570326490908341, 0.9463840126991272]
# [0.1570326490908341, 0.9463840126991272]
# [0.1570326490908341, 0.9463840126991272]
# [0.1570326490908341, 0.9463840126991272]
# [0.1570326490908341, 0.9463840126991272]

# %% [markdown]
# Confusion Matrix
#
# A confusion matrix is a technique for summarizing the performance of a classification algorithm.
#
# For evaluation and performance measurement, the following parameters derived from the confusion matrix are used.
#
# Accuracy = ((TP+TN))/((TP+FN)+(FP+TN))
#
# Precision = TP/((TP+FP))
#
# F1 Score = ((2xTP))/((2xTP+FP+FN))
#
# Recall = ((TP))/((TP+FN))

# %%
#Function to derive the Confusion Matrix

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.tight_layout()
    plt.savefig("ConfusionMatrix for Breast_cancer.jpg", dpi=150)
    plt.show()

# %%
# Threshold predictions with THRESH_VAL

def threshold_arr(array):
    # Get all value from array
    # Compare calue with THRESH_VAL 
    # IF value >= THRESH_VAL. round to 1
    # ELSE. round to 0
    new_arr = []
    for ix, val in enumerate(array):
        loc = np.array(val).argmax(axis=0)
        k = list(np.zeros((len(val)), dtype=np.float32))
        k[loc]=1
        new_arr.append(k)
        
    return np.array(new_arr, dtype=np.float32)

# %% [markdown]
# Plotting of the Confusion Matrix

# %%
# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability

y_preds = threshold_arr(models[4].predict(x, verbose=0))

results = precision_recall_fscore_support(y, y_preds ,average='macro')
acc = accuracy_score(y, y_preds)

print("Accuracy: {}, F1_Score: {}, Precision: {}, Recall: {}".format(acc, results[2], results[0], results[1]))
print("\n")
print(classification_report(y, y_preds))
print("\n")
cnf_matrix = confusion_matrix(y.argmax(axis=1), y_preds.argmax(axis=1))

plot_confusion_matrix(cm           = cnf_matrix, 
                      normalize    = False,
                      target_names = ['BENIGN', 'MALIGNANT'],
                      title        = "Confusion Matrix")
# Out:
# Accuracy: 0.9463840399002493, F1_Score: 0.9365305476416589, Precision: 0.9532964884133093, Recall: 0.9236691718598162
#
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       515
#            1       0.94      0.99      0.96      1089
#
#    micro avg       0.95      0.95      0.95      1604
#    macro avg       0.95      0.92      0.94      1604
# weighted avg       0.95      0.95      0.95      1604
#  samples avg       0.95      0.95      0.95      1604

# %% [markdown]
# Model Prediction
#
# The prediction of the sample with Benign or Malignant is carried out with the help of Model Prediction

# %%
# make predictions on the test data by supplying an image

import time
for i in range(5): 
    img = np.array(Image.open(BASE_DIR+"malignant/SOB/ductal_carcinoma/SOB_M_DC_14-3909/40X/SOB_M_DC-14-3909-40-001.png"))
    x = resize(img, SHAPE)
    x = x.reshape((1,) + x.shape) 
    start = time.time()
    prediction = models[4].predict(x, batch_size=1)
    finish = time.time()
    print(threshold_arr(prediction))
    print((finish-start)*1000,"ms")
    print("***")
# Out:
# [[0. 1.]]
# 219.31767463684082 ms
# ***
# [[0. 1.]]
# 28.545379638671875 ms
# ***
# [[0. 1.]]
# 29.084444046020508 ms
# ***
# [[0. 1.]]
# 31.408309936523438 ms
# ***
# [[0. 1.]]
# 28.725147247314453 ms
# ***

# %% [markdown]
# Plotting of the ROC Curve

# %%
#Plotting the ROC curve

roc_log = roc_auc_score(np.argmax(y, axis=1), np.argmax(y_preds, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(y, axis=1), np.argmax(y_preds, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()
